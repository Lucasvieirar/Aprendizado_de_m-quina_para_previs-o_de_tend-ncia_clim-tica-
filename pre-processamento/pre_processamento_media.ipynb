# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucasvieirar/Aprendizado_de_m-quina_para_previs-o_de_tend-ncia_clim-tica-/blob/main/pre_processamento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("/content/2016_2024-CAMPO_GRANDE.xlsx")

# %%
df.head()
# Out:
#         DATA      HORA  PRECIPITAÇÃO TOTAL, HORÁRIO (mm)  \
# 0 2016-01-01  00:00:00                               0.0
# 1 2016-01-01  01:00:00                               0.0
# 2 2016-01-01  02:00:00                               0.0
# 3 2016-01-01  03:00:00                               0.0
# 4 2016-01-01  04:00:00                               0.0
#
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                              950.8
# 1                                              951.4
# 2                                              951.4
# 3                                              951.0
# 4                                              950.5
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                            950.8
# 1                                            951.4
# 2                                            951.5
# 3                                            951.5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78912 entries, 0 to 78911
# Data columns (total 19 columns):
#  #   Column                                                 Non-Null Count  Dtype
# ---  ------                                                 --------------  -----
#  0   DATA                                                   78912 non-null  datetime64[ns]
#  1   HORA                                                   78912 non-null  object
#  2   PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                       78912 non-null  float64
#  3   PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  78912 non-null  float64
#  4   PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)        78912 non-null  float64
#  5   PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)       78912 non-null  float64
#  6   RADIACAO GLOBAL (KJ/m²)                                78912 non-null  float64
#  7   TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)           78912 non-null  float64
# ...

# %%
df.isnull().sum()
# Out:
# DATA                                                     0
# HORA                                                     0
# PRECIPITAÇÃO TOTAL, HORÁRIO (mm)                         0
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    0
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          0
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         0
# RADIACAO GLOBAL (KJ/m²)                                  0
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)             0
# TEMPERATURA DO PONTO DE ORVALHO (°C)                     0
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)               0
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)               0
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)         0
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)         0
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                 0
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                 0
# UMIDADE RELATIVA DO AR, HORARIA (%)                      0
# ...

# %%
df = df.drop(columns=["DATA","HORA", "PRECIPITAÇÃO TOTAL, HORÁRIO (mm)"])

# %%
df_media = df.groupby(df.index // 24).mean()

# %%
df_media.head()
# Out:
#    PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)  \
# 0                                         950.637500
# 1                                         951.245833
# 2                                         950.916667
# 3                                         951.000000
# 4                                         951.650000
#
#    PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)  \
# 0                                       950.941667
# 1                                       951.541667
# 2                                       951.233333
# 3                                       951.300000
# 4                                       951.975000
#
#    PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)  RADIACAO GLOBAL (KJ/m²)  \
# 0                                        950.312500               420.416667
# 1                                        950.908333               742.150000
# 2                                        950.650000               637.095833
# ...

# %%
(df_media == 0).sum()
# Out:
# PRESSAO ATMOSFERICA AO NIVEL DA ESTACAO, HORARIA (mB)    241
# PRESSÃO ATMOSFERICA MAX.NA HORA ANT. (AUT) (mB)          241
# PRESSÃO ATMOSFERICA MIN. NA HORA ANT. (AUT) (mB)         241
# RADIACAO GLOBAL (KJ/m²)                                  111
# TEMPERATURA DO AR - BULBO SECO, HORARIA (°C)              29
# TEMPERATURA DO PONTO DE ORVALHO (°C)                      29
# TEMPERATURA MÁXIMA NA HORA ANT. (AUT) (°C)                29
# TEMPERATURA MÍNIMA NA HORA ANT. (AUT) (°C)                29
# TEMPERATURA ORVALHO MAX. NA HORA ANT. (AUT) (°C)          29
# TEMPERATURA ORVALHO MIN. NA HORA ANT. (AUT) (°C)          29
# UMIDADE REL. MAX. NA HORA ANT. (AUT) (%)                  29
# UMIDADE REL. MIN. NA HORA ANT. (AUT) (%)                  29
# UMIDADE RELATIVA DO AR, HORARIA (%)                       29
# VENTO, DIREÇÃO HORARIA (gr) (° (gr))                      29
# VENTO, RAJADA MAXIMA (m/s)                                29
# ...

# %%
df_media.to_excel("df_media.xlsx")
